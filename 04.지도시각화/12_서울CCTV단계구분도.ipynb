# %% [markdown]
# ## 서울시 CCTV 구별 단계구분도

# %%
import json, folium
import pandas as pd

# %% [markdown]
# - 데이터 준비하기

# %%
df = pd.read_csv('../02.Pandas/cctv_pop.csv', index_col='구별')
df
# Out:
#          인구수     내국인    외국인    고령자     외국인비율      고령자비율  CCTV댓수      최근 증가율
# 구별
# 종로구   153789  144683   9106  27818  5.921100  18.088420    1715   20.689655
# 중구    131787  122499   9288  24392  7.047736  18.508654    2447   78.984238
# 용산구   237285  222953  14332  39070  6.039994  16.465432    2611   78.635682
# 성동구   292672  285990   6682  46380  2.283102  15.847092    3829   63.485477
# 광진구   352627  339996  12631  51723  3.581972  14.667907    3211  112.292359
# 동대문구  352006  337400  14606  62211  4.149361  17.673278    2628   36.332767
# 중랑구   391885  387350   4535  71682  1.157227  18.291591    3737  190.547703
# 성북구   440142  430528   9614  74709  2.184295  16.973840    4602   77.580372
# 강북구   302563  299182   3381  64333  1.117453  21.262679    3090  429.292929
# 도봉구   319373  317366   2007  64160  0.628419  20.089363    1930   85.436893
# 노원구   514946  510956   3990  88345  0.774839  17.156168    2492   68.471810
# ...

# %%
filename = 'skorea_municipalities_geo_simple.json'
geo_str = json.load(open(filename, encoding='utf-8'))

# %% [markdown]
# - 단계구분도(Choropleth)

# %%
map = folium.Map(location=[37.5502, 126.9820], zoom_start=11, tiles='Stamen Toner')
folium.Choropleth(
    geo_data=geo_str,
    data=df.CCTV댓수,
    columns=[df.index, df.CCTV댓수],
    fill_color='PuRd',
    key_on='feature.id'
).add_to(map)
title_html = '<h3 align="center", stle="font-size=20px">구별 CCTV 댓수</h3>'
map.get_root().html.add_child(folium.Element(title_html))
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# - 구 이름 표시하기(좌표, 텍스트)

# %%
import numpy as np

def get_text_location(geo_str):
    gu_dict = {}
    for gu in geo_str['features']:
        for coord in gu['geometry']['coordinates']:
            geo = np.array(coord)
            gu_dict[gu['id']] = [np.mean(geo[:,1]), np.mean(geo[:,0])]
    return gu_dict

# %%
from folium.features import DivIcon

gu_dict = get_text_location(geo_str)

# %%
map = folium.Map(location=[37.5502, 126.9820], zoom_start=11, tiles='Stamen Toner')
folium.Choropleth(
    geo_data=geo_str,
    data=df.CCTV댓수,
    columns=[df.index, df.CCTV댓수],
    fill_color='YlGnBu',
    key_on='feature.id'
).add_to(map)
for gu_name in df.index:
    folium.Marker(
        location=gu_dict[gu_name],
        icon=DivIcon(icon_size=(80,20), icon_anchor=(20,0),
            html=f'<div style="font-size:10pt">{gu_name}</div>'
        )
    ).add_to(map)
map.get_root().html.add_child(folium.Element(title_html))
title_html = '<h3 align="center", stle="font-size=20px">구별 CCTV 댓수</h3>'
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# - 구별 CCTV 최근 증가율

# %%
map = folium.Map(location=[37.5502, 126.9820], zoom_start=11, tiles='Stamen Toner')
folium.Choropleth(
    geo_data=geo_str,
    data=df.iloc[:,7],
    columns=[df.index, df.iloc[:,7]],
    fill_color='YlOrRd',
    key_on='feature.id'
).add_to(map)
for gu_name in df.index:
    folium.Marker(
        location=gu_dict[gu_name],
        icon=DivIcon(icon_size=(80,20), icon_anchor=(20,0),
            html=f'<div style="font-size:10pt">{gu_name}</div>'
        )
    ).add_to(map)
title_html = '<h3 align="center", stle="font-size=20px">구별 CCTV 최근 증가율</h3>'
map.get_root().html.add_child(folium.Element(title_html))
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
